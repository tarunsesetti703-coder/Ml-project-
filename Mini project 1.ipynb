# %% [markdown]
# # Mini Project 1

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#          Date       city  Temperature_c  Humidity_% Condition
# 0  01-01-2025  Hyderabad             28          60     Sunny
# 1  02-01-2025  Hyderabad             29          62    Cloudy
# 2  03-01-2025  Hyderabad             30          58     Rainy
# 3  04-01-2025   Banglore             31          55     Sunny
# 4  05-01-2025  Hyderabad             32          63    Cloudy
# 5  06-01-2025  Hyderabad             33          59     Rainy
# 6  07-01-2025   Banglore             34          54     Sunny

# %% [markdown]
# # Exploring Data

# %%
df.head()
# Out:
#          Date       city  Temperature_c  Humidity_% Condition
# 0  01-01-2025  Hyderabad             28          60     Sunny
# 1  02-01-2025  Hyderabad             29          62    Cloudy
# 2  03-01-2025  Hyderabad             30          58     Rainy
# 3  04-01-2025   Banglore             31          55     Sunny
# 4  05-01-2025  Hyderabad             32          63    Cloudy

# %%
df.tail()
# Out:
#          Date       city  Temperature_c  Humidity_% Condition
# 2  03-01-2025  Hyderabad             30          58     Rainy
# 3  04-01-2025   Banglore             31          55     Sunny
# 4  05-01-2025  Hyderabad             32          63    Cloudy
# 5  06-01-2025  Hyderabad             33          59     Rainy
# 6  07-01-2025   Banglore             34          54     Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           7 non-null      object
#  1   city           7 non-null      object
#  2   Temperature_c  7 non-null      int64
#  3   Humidity_%     7 non-null      int64
#  4   Condition      7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %%
df.shape
# Out:
# (7, 5)

# %%
df[2:5]
# Out:
#          Date       city  Temperature_c  Humidity_% Condition
# 2  03-01-2025  Hyderabad             30          58     Rainy
# 3  04-01-2025   Banglore             31          55     Sunny
# 4  05-01-2025  Hyderabad             32          63    Cloudy

# %%
df.columns
# Out:
# Index(['Date', 'city', 'Temperature_c', 'Humidity_%', 'Condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.dtypes
# Out:
# Date             object
# city             object
# Temperature_c     int64
# Humidity_%        int64
# Condition        object
# dtype: object

# %%
df.Date
# Out:
# 0    01-01-2025
# 1    02-01-2025
# 2    03-01-2025
# 3    04-01-2025
# 4    05-01-2025
# 5    06-01-2025
# 6    07-01-2025
# Name: Date, dtype: object

# %%
df['Date']
# Out:
# 0    01-01-2025
# 1    02-01-2025
# 2    03-01-2025
# 3    04-01-2025
# 4    05-01-2025
# 5    06-01-2025
# 6    07-01-2025
# Name: Date, dtype: object

# %%
df[['Date','Condition']]
# Out:
#          Date Condition
# 0  01-01-2025     Sunny
# 1  02-01-2025    Cloudy
# 2  03-01-2025     Rainy
# 3  04-01-2025     Sunny
# 4  05-01-2025    Cloudy
# 5  06-01-2025     Rainy
# 6  07-01-2025     Sunny

# %%
df['Date'][df['Condition']=='Sunny']
# Out:
# 0    01-01-2025
# 3    04-01-2025
# 6    07-01-2025
# Name: Date, dtype: object

# %% [markdown]
# # Reading Data

# %%
alpha_df=pd.DataFrame({
    "abc":["Apple","Ball","Cat","Dog","Egg"],
    "num":[17,7,30,47,49],
    "name":["Ajay","Satish","Deeven","Abhi","Tarun"]
})
alpha_df
# Out:
#      abc  num    name
# 0  Apple   17    Ajay
# 1   Ball    7  Satish
# 2    Cat   30  Deeven
# 3    Dog   47    Abhi
# 4    Egg   49   Tarun

# %%
alpha_df.head(2)
# Out:
#      abc  num    name
# 0  Apple   17    Ajay
# 1   Ball    7  Satish

# %%
alpha_df.tail(3)
# Out:
#    abc  num    name
# 2  Cat   30  Deeven
# 3  Dog   47    Abhi
# 4  Egg   49   Tarun

# %%
alpha_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   abc     5 non-null      object
#  1   num     5 non-null      int64
#  2   name    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
alpha_df.shape
# Out:
# (5, 3)

# %%
alpha_df[2:3]
# Out:
#    abc  num    name
# 2  Cat   30  Deeven

# %%
alpha_df.columns
# Out:
# Index(['abc', 'num', 'name'], dtype='object')

# %%
alpha_df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
alpha_df.dtypes
# Out:
# abc     object
# num      int64
# name    object
# dtype: object

# %%
alpha_df.abc
# Out:
# 0    Apple
# 1     Ball
# 2      Cat
# 3      Dog
# 4      Egg
# Name: abc, dtype: object

# %%
alpha_df['num']
# Out:
# 0    17
# 1     7
# 2    30
# 3    47
# 4    49
# Name: num, dtype: int64
