# %% [markdown]
# # Statistics Methods

# %%
import pandas as pd

# %%
df=pd.read_csv("study_marks.csv")
df
# Out:
#    Study_Hours  Marks
# 0          2.9   27.0
# 1          5.8   61.0
# 2          4.7   45.0
# 3          4.0   38.0
# 4          1.8   19.0
# 5          1.8    8.0
# 6          1.3    4.0
# 7          5.3   50.0
# 8          4.0   35.0
# 9          4.5   47.0

# %%
df['Marks'].max()
# Out:
# np.float64(61.0)

# %%
df['Marks'].min()
# Out:
# np.float64(4.0)

# %%
df['Marks'].describe()
# Out:
# count    10.000000
# mean     33.400000
# std      18.673808
# min       4.000000
# 25%      21.000000
# 50%      36.500000
# 75%      46.500000
# max      61.000000
# Name: Marks, dtype: float64

# %%
df['Marks'].mean()
# Out:
# np.float64(33.4)

# %%
df.count()
# Out:
# Study_Hours    10
# Marks          10
# dtype: int64

# %%
df.sum()
# Out:
# Study_Hours     36.1
# Marks          334.0
# dtype: float64

# %%
df.cov()
# Out:
#              Study_Hours       Marks
# Study_Hours     2.481000   28.906667
# Marks          28.906667  348.711111

# %%
df.corr()
# Out:
#              Study_Hours    Marks
# Study_Hours      1.00000  0.98277
# Marks            0.98277  1.00000

# %%
df.skew()
# Out:
# Study_Hours   -0.252158
# Marks         -0.325708
# dtype: float64

# %%
df.kurt()
# Out:
# Study_Hours   -1.380748
# Marks         -0.898525
# dtype: float64

# %%
df.value_counts()
# Out:
# Study_Hours  Marks
# 1.3          4.0      1
# 1.8          8.0      1
#              19.0     1
# 2.9          27.0     1
# 4.0          35.0     1
#              38.0     1
# 4.5          47.0     1
# 4.7          45.0     1
# 5.3          50.0     1
# 5.8          61.0     1
# Name: count, dtype: int64

# %%
df["Study_Hours"].nunique()
# Out:
# 8

# %%
df['Study_Hours'].median()
# Out:
# np.float64(4.0)

# %%
df["Marks"].value_counts()
# Out:
# Marks
# 27.0    1
# 61.0    1
# 45.0    1
# 38.0    1
# 19.0    1
# 8.0     1
# 4.0     1
# 50.0    1
# 35.0    1
# 47.0    1
# Name: count, dtype: int64

# %%
df[df.Study_Hours == df.Study_Hours.max()]
# Out:
#    Study_Hours  Marks
# 1          5.8   61.0

# %%
df.Study_Hours[df.Marks == df.Marks.max()]
# Out:
# 1    5.8
# Name: Study_Hours, dtype: float64

# %%
df.Study_Hours[df.Marks == df.Marks.min()]
# Out:
# 6    1.3
# Name: Study_Hours, dtype: float64
